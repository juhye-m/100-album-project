# %%
# imports
from dotenv import load_dotenv
import os
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from IPython.display import display
import numpy as np

# %%
# load env variables
load_dotenv()

# get the client id and secret from the env
client_id = os.getenv('SPOTIPY_CLIENT_ID')
client_secret = os.getenv('SPOTIPY_CLIENT_SECRET')

# %%
# set up spotipy with my client credentials. use the sp object to call methods / interact with the api
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=client_id, client_secret=client_secret))

# %%
# Set pandas to display longer content without truncation
# pd.set_option('display.max_colwidth', None)  # No limit on column width
# pd.set_option('display.max_rows', None)      # No limit on rows displayed

# %%
# format time duration
def format_duration(duration_ms):
    # HH:MM:SS format
    seconds = (duration_ms // 1000) % 60
    minutes = (duration_ms // (1000 * 60)) % 60
    hours = (duration_ms // (1000 * 60 * 60))
    return f"{hours}:{minutes:02}:{seconds:02}"

# %%
def get_tracks_for_album(album_id):
    album_tracks = sp.album_tracks(album_id)
    return album_tracks['items']

# %%
def get_song_features(track_id):
    song_features = sp.audio_features(track_id)
    return song_features[0] if song_features else None

# %%
# this is a list of dicts, and which track it comes from is unspecified
def get_all_audio_features(track_ids):
    features_list = []
    for track_id in track_ids:
        features = get_song_features(track_id)
        if features:
            features_list.append(features)
    return features_list

# %%
# function to calculate mean/median/mode of any audio feature
def calculate_average_features(audio_features, feature_list):
    if not audio_features:
        return None
    
    # df from the audio features in the list of dicts provided
    features_df = pd.DataFrame(audio_features)

    display(features_df)

    # the mean for the specified features, while appending "_avg" to the col name using rename and a lamba func
    mean_features = features_df[feature_list].mean().rename(lambda x: f"{x}_avg").to_dict()

    # if i didnt want to change the col name, i'd just do this:
    # mean_features = features_df[feature_list].mean().to_dict()

    # dict of avg values for the specified features
    # print(mean_features)
    return mean_features

# %%
# function that takes in album and artist, and outputs the album info
def get_album_info(album_title, artist_name):
    query = f'album:{album_title} artist:{artist_name}' # spotify api syntax for this search query
    result = sp.search(q=query, type='album', limit=1) # returns the album, 1
    
    # print(result)
    if result['albums']['items']:
        # parse JSON to get the first (and only) album for its info
        album = result['albums']['items'][0]
        album_id = album['id']

        # detailed info like genre and popularity
        album_details = sp.album(album['id'])
        print(album_details['popularity'])
        # print(album_details['genres'])

        # Get album tracks
        tracks = get_tracks_for_album(album_id)

        # track duration sum for album duration
        track_durations = [track['duration_ms'] for track in tracks]
        total_duration_ms = sum(track_durations)
        print(format_duration(total_duration_ms))

        # extract details from JSON and put into new dict of info for the album
        album_data = {
            'album_title': album['name'],
            'album_id': album['id'],
            'artist_name': album['artists'][0]['name'], #this is just 1 artist for now, but later can make a list if theres multiple primary artists
            'release_date': album['release_date'],
            'total_tracks': album['total_tracks'],
            'duration_ms': total_duration_ms,
            'duration': format_duration(total_duration_ms),
            'genres': album.get('genres', []), #avoid error if no genres specified
            'popularity': album_details['popularity'],
            'uri': album['uri']
        }
        return album_data
    else:
        return None

# %%
def read_csv(file_path):
    return pd.read_csv(file_path)

# %%
# Main function
def main():
    # csv file path
    csv_file_path = 'albums.csv'

    # read csv into pandas dataframe
    df = read_csv(csv_file_path)

    # process the df 
    album_data_list = []
    # go through each row of the df (each album) and get the data 
    for index, row in df.iterrows():
        album_title = row['album_title']
        artist_name = row['artist_name']

        album_data = get_album_info(album_title, artist_name)

        # individual track data for the album
        if album_data:
            track_ids = [track['id'] for track in get_tracks_for_album(album_data['album_id'])]
            audio_features = get_all_audio_features(track_ids)
            album_data['audio_features'] = audio_features  # Store audio features in the album data
            # print(album_data['audio_features'])

            # calculate avg audio features (e.g. danceability, energy)
            features_to_average = ['tempo', 'valence', 'danceability', 'energy', 'acousticness', 'liveness', 'loudness','speechiness'] # later, keep track of mode for key and time signature? or need specifics # of a certain key/time sig? will compare at the end across all albums accumulated
            avg_features = calculate_average_features(audio_features, features_to_average) #returns dict of features avg

            # add the average features dict to the album data dict
            album_data.update(avg_features)

            # keep in mind the avg of avgs across other albums isnt the same mathematically, if i were to want to do track data (like finding the mode for the keys etc as i noted above)

            print(f"Album: {album_data['album_title']} by {album_data['artist_name']}")
            for feature, avg_value in avg_features.items():
                print(f"Average {feature.capitalize()}: {avg_value:.2f}")

            # appends album data to the list of albums' datas
            # check/print this
            album_data_list.append(album_data)

    # convert this album data list to a new df with all the info it pulled
    album_data_df = pd.DataFrame(album_data_list)

    # here, we can analyze the data or do more with it
    # print(album_data_df)
    # print(type(album_data_df))
    # print(album_data_df.head())  # Show first few rows to confirm content

    # album_data_df # in jupyter notebook, this shows the df
    # album_data_df.head()  # Shows the first 5 rows

    display(album_data_df)

    # output the average length (calculate)
        # Calculate average album length
    if not album_data_df.empty:
        print(int(album_data_df['duration_ms'].mean()))
        average_length = int(album_data_df['duration_ms'].mean())
        print(f'Average album duration: {format_duration(average_length)} minutes')
    # else:
    #     print('No album data available.')

    # access genre by album title
    # album_title = 'GUTS'
    # first_album_genre = album_data_df[album_data_df['album_title'] == album_title]['genres'].values[0]
    # print(first_album_genre)

    # audio features average
    # print(album_data_df['audio_features'])

# hii

# %%
main()
# Out:
# 88
# 0:39:18
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.421   0.695    6    -4.346     1       0.0428       0.21800
# 1          0.631   0.881    9    -3.545     1       0.0995       0.00177
# 2          0.484   0.530    5    -5.821     1       0.0538       0.15400
# 3          0.395   0.367    3    -7.653     1       0.0324       0.81500
# 4          0.351   0.884    1    -3.452     1       0.0740       0.06230
# 5          0.550   0.409    7    -7.718     1       0.0316       0.38600
# 6          0.480   0.240    7    -8.146     1       0.0323       0.84400
# 7          0.553   0.847    5    -5.736     1       0.1870       0.01430
# 8          0.517   0.821    9    -3.504     1       0.1050       0.00341
# 9          0.511   0.313   10    -9.320     1       0.0846       0.90500
# 10         0.559   0.845    2    -4.394     1       0.0501       0.00243
# 11         0.426   0.218    0   -11.705     1       0.0341       0.83500
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.000003    0.1550    0.450  156.344  audio_features
# 1           0.000005    0.0639    0.808  129.981  audio_features
# 2           0.000000    0.2630    0.323  136.848  audio_features
# 3           0.000000    0.1100    0.426   77.968  audio_features
# 4           0.000000    0.3350    0.408  120.166  audio_features
# 5           0.000000    0.1220    0.252  133.099  audio_features
# 6           0.000000    0.0990    0.152   80.686  audio_features
# 7           0.000000    0.5610    0.733  162.024  audio_features
# 8           0.000000    0.1480    0.617  160.052  audio_features
# 9           0.000000    0.0832    0.331  126.962  audio_features
# 10          0.000001    0.0726    0.566  123.941  audio_features
# 11          0.000000    0.1080    0.116  135.205  audio_features
#
#                         id                                   uri  \
# 0   34sOdxWu9FljH84UXdRwu1  spotify:track:34sOdxWu9FljH84UXdRwu1
# 1   3IX0yuEVvDbnqUwMBB3ouC  spotify:track:3IX0yuEVvDbnqUwMBB3ouC
# 2   1kuGVB7EU95pJObxwvfwKS  spotify:track:1kuGVB7EU95pJObxwvfwKS
# 3   6QT6j7rKt7Vk3IuV2AUO9W  spotify:track:6QT6j7rKt7Vk3IuV2AUO9W
# 4   5sp71CUt0jXRNqHblPGp7b  spotify:track:5sp71CUt0jXRNqHblPGp7b
# 5   5CscrLqFBgPfZR8fGtikov  spotify:track:5CscrLqFBgPfZR8fGtikov
# 6   53dtP2iUMvaF28JZcHnFuU  spotify:track:53dtP2iUMvaF28JZcHnFuU
# 7   2gyxAWHebV7xPYVxqoi86f  spotify:track:2gyxAWHebV7xPYVxqoi86f
# 8   26QLJMK8G0M06sk7h7Fkse  spotify:track:26QLJMK8G0M06sk7h7Fkse
# 9   3Nl5OkkmS5DaBZvuYofpAt  spotify:track:3Nl5OkkmS5DaBZvuYofpAt
# 10  6W9l02gRsXVxzIuQC1oc1X  spotify:track:6W9l02gRsXVxzIuQC1oc1X
# 11  7fesNTgTEMEH0ye8MOgEDY  spotify:track:7fesNTgTEMEH0ye8MOgEDY
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/34sOdxWu9Flj...
# 1   https://api.spotify.com/v1/tracks/3IX0yuEVvDbn...
# 2   https://api.spotify.com/v1/tracks/1kuGVB7EU95p...
# 3   https://api.spotify.com/v1/tracks/6QT6j7rKt7Vk...
# 4   https://api.spotify.com/v1/tracks/5sp71CUt0jXR...
# 5   https://api.spotify.com/v1/tracks/5CscrLqFBgPf...
# 6   https://api.spotify.com/v1/tracks/53dtP2iUMvaF...
# 7   https://api.spotify.com/v1/tracks/2gyxAWHebV7x...
# 8   https://api.spotify.com/v1/tracks/26QLJMK8G0M0...
# 9   https://api.spotify.com/v1/tracks/3Nl5OkkmS5Da...
# 10  https://api.spotify.com/v1/tracks/6W9l02gRsXVx...
# 11  https://api.spotify.com/v1/tracks/7fesNTgTEMEH...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/34sO...       165834
# 1   https://api.spotify.com/v1/audio-analysis/3IX0...       184784
# 2   https://api.spotify.com/v1/audio-analysis/1kuG...       219724
# 3   https://api.spotify.com/v1/audio-analysis/6QT6...       177212
# 4   https://api.spotify.com/v1/audio-analysis/5sp7...       203369
# 5   https://api.spotify.com/v1/audio-analysis/5Csc...       198867
# 6   https://api.spotify.com/v1/audio-analysis/53dt...       231907
# 7   https://api.spotify.com/v1/audio-analysis/2gyx...       211141
# 8   https://api.spotify.com/v1/audio-analysis/26QL...       154517
# 9   https://api.spotify.com/v1/audio-analysis/3Nl5...       189386
# 10  https://api.spotify.com/v1/audio-analysis/6W9l...       199422
# 11  https://api.spotify.com/v1/audio-analysis/7fes...       222358
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# 5                4
# 6                4
# 7                4
# 8                4
# 9                4
# 10               4
# 11               4
# Album: GUTS by Olivia Rodrigo
# Average Tempo_avg: 128.61
# Average Valence_avg: 0.43
# Average Danceability_avg: 0.49
# Average Energy_avg: 0.59
# Average Acousticness_avg: 0.35
# Average Liveness_avg: 0.18
# Average Loudness_avg: -6.28
# Average Speechiness_avg: 0.07
# 92
# 0:34:46
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.672   0.526    4    -6.446     1       0.0599        0.0311
# 1          0.380   0.339    3    -7.885     1       0.0338        0.6910
# 2          0.561   0.431   10    -8.810     1       0.0578        0.7680
# 3          0.473   0.203    2   -12.627     1       0.1020        0.9410
# 4          0.442   0.612    2    -7.222     1       0.1120        0.5840
# 5          0.563   0.664    9    -5.044     1       0.1540        0.3350
# 6          0.638   0.259    7   -10.706     1       0.0898        0.7530
# 7          0.395   0.443    6    -9.720     1       0.1330        0.7650
# 8          0.695   0.575   10    -6.334     0       0.1160        0.1980
# 9          0.369   0.272    9   -10.497     1       0.0364        0.8660
# 10         0.443   0.298    0   -12.181     1       0.0644        0.3880
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.000001    0.2800   0.2800  123.999  audio_features
# 1           0.000000    0.1200   0.0849  100.607  audio_features
# 2           0.000014    0.1060   0.1370  143.875  audio_features
# 3           0.000000    0.1260   0.4190  168.884  audio_features
# 4           0.000006    0.3700   0.1780  180.917  audio_features
# 5           0.000000    0.0849   0.6880  166.928  audio_features
# 6           0.000000    0.2190   0.2690   88.485  audio_features
# 7           0.000010    0.0839   0.3380  168.924  audio_features
# 8           0.000000    0.0614   0.6990  163.929  audio_features
# 9           0.000000    0.1470   0.2180  172.929  audio_features
# 10          0.000010    0.1030   0.1720   77.253  audio_features
#
#                         id                                   uri  \
# 0   6SRsiMl7w1USE4mFqrOhHC  spotify:track:6SRsiMl7w1USE4mFqrOhHC
# 1   5CZ40GBx1sQ9agT82CLQCT  spotify:track:5CZ40GBx1sQ9agT82CLQCT
# 2   5wANPM4fQCJwkGd4rN57mH  spotify:track:5wANPM4fQCJwkGd4rN57mH
# 3   4wcBRRpIfesgcyUtis7PEg  spotify:track:4wcBRRpIfesgcyUtis7PEg
# 4   6HU7h9RYOaPRFeh0R3UeAr  spotify:track:6HU7h9RYOaPRFeh0R3UeAr
# 5   4ZtFanR9U6ndgddUvNcjcG  spotify:track:4ZtFanR9U6ndgddUvNcjcG
# 6   2TOzTqQXNmR2zDJXihjZ2e  spotify:track:2TOzTqQXNmR2zDJXihjZ2e
# 7   2tGvwE8GcFKwNdAXMnlbfl  spotify:track:2tGvwE8GcFKwNdAXMnlbfl
# 8   0MMyJUC3WNnFS1lit5pTjk  spotify:track:0MMyJUC3WNnFS1lit5pTjk
# 9   5JCoSi02qi3jJeHdZXMmR8  spotify:track:5JCoSi02qi3jJeHdZXMmR8
# 10  1zejeOnykpCoyVSit6Bwp3  spotify:track:1zejeOnykpCoyVSit6Bwp3
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/6SRsiMl7w1US...
# 1   https://api.spotify.com/v1/tracks/5CZ40GBx1sQ9...
# 2   https://api.spotify.com/v1/tracks/5wANPM4fQCJw...
# 3   https://api.spotify.com/v1/tracks/4wcBRRpIfesg...
# 4   https://api.spotify.com/v1/tracks/6HU7h9RYOaPR...
# 5   https://api.spotify.com/v1/tracks/4ZtFanR9U6nd...
# 6   https://api.spotify.com/v1/tracks/2TOzTqQXNmR2...
# 7   https://api.spotify.com/v1/tracks/2tGvwE8GcFKw...
# 8   https://api.spotify.com/v1/tracks/0MMyJUC3WNnF...
# 9   https://api.spotify.com/v1/tracks/5JCoSi02qi3j...
# 10  https://api.spotify.com/v1/tracks/1zejeOnykpCo...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/6SRs...       143747
# 1   https://api.spotify.com/v1/audio-analysis/5CZ4...       229227
# 2   https://api.spotify.com/v1/audio-analysis/5wAN...       242013
# 3   https://api.spotify.com/v1/audio-analysis/4wcB...       163587
# 4   https://api.spotify.com/v1/audio-analysis/6HU7...       215507
# 5   https://api.spotify.com/v1/audio-analysis/4ZtF...       178147
# 6   https://api.spotify.com/v1/audio-analysis/2TOz...       202827
# 7   https://api.spotify.com/v1/audio-analysis/2tGv...       175933
# 8   https://api.spotify.com/v1/audio-analysis/0MMy...       173160
# 9   https://api.spotify.com/v1/audio-analysis/5JCo...       152667
# 10  https://api.spotify.com/v1/audio-analysis/1zej...       209560
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# 5                4
# 6                4
# 7                3
# 8                4
# 9                4
# 10               4
# Album: SOUR by Olivia Rodrigo
# Average Tempo_avg: 141.52
# Average Valence_avg: 0.32
# Average Danceability_avg: 0.51
# Average Energy_avg: 0.42
# Average Acousticness_avg: 0.57
# Average Liveness_avg: 0.15
# Average Loudness_avg: -8.86
# Average Speechiness_avg: 0.09
# 84
# 0:41:10
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.729   0.476    8    -4.985     1       0.0363        0.3780
# 1          0.647   0.309    7    -7.948     0       0.0367        0.7780
# 2          0.747   0.459    6    -6.891     1       0.3060        0.4480
# 3          0.757   0.665    2    -5.194     0       0.0774        0.0815
# 4          0.450   0.619    9    -7.412     1       0.3730        0.3290
# 5          0.847   0.579    1    -5.314     1       0.0720        0.0268
# 6          0.710   0.715    7    -5.371     1       0.1920        0.0845
# 7          0.290   0.364    9    -8.295     1       0.0293        0.4180
# 8          0.662   0.600    0    -6.403     1       0.0704        0.1730
# 9          0.777   0.317    1   -10.732     0       0.3080        0.5910
# 10         0.720   0.654    1    -5.634     1       0.0647        0.2270
# 11         0.727   0.554    5    -5.290     0       0.0915        0.0421
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.000000    0.1200    0.368   62.519  audio_features
# 1           0.000007    0.2020    0.195   87.046  audio_features
# 2           0.000000    0.2520    0.470   75.021  audio_features
# 3           0.000158    0.2160    0.643  151.979  audio_features
# 4           0.000000    0.3190    0.427   83.221  audio_features
# 5           0.054600    0.1020    0.569  137.998  audio_features
# 6           0.000001    0.0617    0.479  105.044  audio_features
# 7           0.000019    0.1850    0.110  103.684  audio_features
# 8           0.000137    0.1090    0.331  134.972  audio_features
# 9           0.000000    0.0881    0.330  139.848  audio_features
# 10          0.000000    0.1010    0.411  106.976  audio_features
# 11          0.000000    0.1060    0.335  170.000  audio_features
#
#                         id                                   uri  \
# 0   39LmTF9RgyakzSYX8txrow  spotify:track:39LmTF9RgyakzSYX8txrow
# 1   1TEL6MlSSVLSdhOSddidlJ  spotify:track:1TEL6MlSSVLSdhOSddidlJ
# 2   4uTvPEr01pjTbZgl7jcKBD  spotify:track:4uTvPEr01pjTbZgl7jcKBD
# 3   2hloaUoRonYssMuqLCBLTX  spotify:track:2hloaUoRonYssMuqLCBLTX
# 4   3wFLWP0FcIqHK1wb1CPthQ  spotify:track:3wFLWP0FcIqHK1wb1CPthQ
# 5   5Il6Oe7lr5XM7A0cWbVQtr  spotify:track:5Il6Oe7lr5XM7A0cWbVQtr
# 6   27356GVuMPFWiJSZCragoM  spotify:track:27356GVuMPFWiJSZCragoM
# 7   2vdBo4ALPYbHRUPKgtE5iC  spotify:track:2vdBo4ALPYbHRUPKgtE5iC
# 8   4T652DlATVHe0jdLKaN3Bw  spotify:track:4T652DlATVHe0jdLKaN3Bw
# 9   6ocbgoVGwYJhOv1GgI9NsF  spotify:track:6ocbgoVGwYJhOv1GgI9NsF
# 10  3e9HZxeyfWwjeyPAMmWSSQ  spotify:track:3e9HZxeyfWwjeyPAMmWSSQ
# 11  4kV4N9D1iKVxx1KLvtTpjS  spotify:track:4kV4N9D1iKVxx1KLvtTpjS
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/39LmTF9Rgyak...
# 1   https://api.spotify.com/v1/tracks/1TEL6MlSSVLS...
# 2   https://api.spotify.com/v1/tracks/4uTvPEr01pjT...
# 3   https://api.spotify.com/v1/tracks/2hloaUoRonYs...
# 4   https://api.spotify.com/v1/tracks/3wFLWP0FcIqH...
# 5   https://api.spotify.com/v1/tracks/5Il6Oe7lr5XM...
# 6   https://api.spotify.com/v1/tracks/27356GVuMPFW...
# 7   https://api.spotify.com/v1/tracks/2vdBo4ALPYbH...
# 8   https://api.spotify.com/v1/tracks/4T652DlATVHe...
# 9   https://api.spotify.com/v1/tracks/6ocbgoVGwYJh...
# 10  https://api.spotify.com/v1/tracks/3e9HZxeyfWwj...
# 11  https://api.spotify.com/v1/tracks/4kV4N9D1iKVx...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/39Lm...       212267
# 1   https://api.spotify.com/v1/audio-analysis/1TEL...       171573
# 2   https://api.spotify.com/v1/audio-analysis/4uTv...       182000
# 3   https://api.spotify.com/v1/audio-analysis/2hlo...       216893
# 4   https://api.spotify.com/v1/audio-analysis/3wFL...       208880
# 5   https://api.spotify.com/v1/audio-analysis/5Il6...       267107
# 6   https://api.spotify.com/v1/audio-analysis/2735...       140693
# 7   https://api.spotify.com/v1/audio-analysis/2vdB...       271467
# 8   https://api.spotify.com/v1/audio-analysis/4T65...       222947
# 9   https://api.spotify.com/v1/audio-analysis/6ocb...       178627
# 10  https://api.spotify.com/v1/audio-analysis/3e9H...       207320
# 11  https://api.spotify.com/v1/audio-analysis/4kV4...       190440
#
#     time_signature
# 0                3
# 1                4
# 2                4
# 3                4
# 4                4
# 5                4
# 6                3
# 7                4
# 8                4
# 9                4
# 10               4
# 11               4
# Album: thank u, next by Ariana Grande
# Average Tempo_avg: 113.19
# Average Valence_avg: 0.39
# Average Danceability_avg: 0.67
# Average Energy_avg: 0.53
# Average Acousticness_avg: 0.30
# Average Liveness_avg: 0.16
# Average Loudness_avg: -6.62
# Average Speechiness_avg: 0.14
#      album_title                album_id     artist_name release_date  \
# 0           GUTS  1xJHno7SmdVtZAtXbdbDZp  Olivia Rodrigo   2023-09-08
# 1           SOUR  6s84u2TUpR3wdUv4NgKA2j  Olivia Rodrigo   2021-05-21
# 2  thank u, next  2fYhqwDWXjbpjaIJPEfKFw   Ariana Grande   2019-02-08
#
#    total_tracks  duration_ms duration genres  popularity  \
# 0            12      2358517  0:39:18     []          88
# 1            11      2086368  0:34:46     []          92
# 2            12      2470209  0:41:10     []          84
#
#                                     uri  \
# 0  spotify:album:1xJHno7SmdVtZAtXbdbDZp
# 1  spotify:album:6s84u2TUpR3wdUv4NgKA2j
# 2  spotify:album:2fYhqwDWXjbpjaIJPEfKFw
#
#                                       audio_features   tempo_avg  valence_avg  \
# 0  [{'danceability': 0.421, 'energy': 0.695, 'key...  128.606333     0.431833
# 1  [{'danceability': 0.672, 'energy': 0.526, 'key...  141.520909     0.316627
# 2  [{'danceability': 0.729, 'energy': 0.476, 'key...  113.192333     0.389000
#
#    danceability_avg  energy_avg  acousticness_avg  liveness_avg  loudness_avg  \
# 0          0.489833    0.587500          0.353434      0.176725     -6.278333
# 1          0.511909    0.420182          0.574555      0.154655     -8.861091
# 2          0.671917    0.525917          0.298075      0.155150     -6.622417
#
#    speechiness_avg
# 0         0.068933
# 1         0.087191
# 2         0.138108
# 2305031
# Average album duration: 0:38:25 minutes
